# %% [markdown]
# <a href="https://colab.research.google.com/github/Rushikesh419/credit-card-fraud-detection/blob/main/credit_card_fraud_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pylab import rcParams
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('/content/drive/MyDrive/creditcard.csv')
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
data.shape
# Out:
# (284807, 31)

# %%
data[["Time", "Amount", "Class"]].describe()
# Out:
#                 Time         Amount          Class
# count  284807.000000  284807.000000  284807.000000
# mean    94813.859575      88.349619       0.001727
# std     47488.145955     250.120109       0.041527
# min         0.000000       0.000000       0.000000
# 25%     54201.500000       5.600000       0.000000
# 50%     84692.000000      22.000000       0.000000
# 75%    139320.500000      77.165000       0.000000
# max    172792.000000   25691.160000       1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# FRAUD CASES AND GENUINE CASES

# %%
fraud = data[data["Class"] == 1]
not_fraud = data[data["Class"] == 0]
data['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
print(fraud.shape)
print(not_fraud.shape)
# Out:
# (492, 31)
# (284315, 31)

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
not_fraud.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %% [markdown]
# Let's examine the distributions of the time of transactions and the transaction amounts to gain insights into the skewness of these features.

# %%
data.hist(figsize=(20,20),color='lime')
plt.show()

# %%
# Create subplots
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Use histplot for distribution plots
sns.histplot(data['Time'], ax = ax1, color='b', kde = True)
sns.histplot(data['Amount'], ax = ax2, color='r', kde = True)

# Set titles for the subplots
ax1.set_title('Distribution of Time', fontsize = 13)
ax2.set_title('Distribution of Amount', fontsize = 13)

# Show the plots
plt.show()

# %%
plt.figure(figsize = (14,14))
plt.title('Credit Card Transactions features correlation plot (Pearson)')
corr = data.corr()
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, linewidths=.1)
plt.show()

# %% [markdown]
# Features Correlations
#
# There is no notable correlation between features V1-V28.

# %% [markdown]
# Now lets create a plot that displays the relationship between the amount of fraudulent transactions and the corresponding time in seconds from the beginning of the time period.

# %%
rcParams['figure.figsize'] = 16, 8
f,(ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Time of transaction vs Amount by class')
ax1.scatter(fraud.Time, fraud.Amount)
ax1.set_title('Fraud')
ax2.scatter(not_fraud.Time, not_fraud.Amount)
ax2.set_title('Genuine')
plt.xlabel('Time (in Seconds)')
plt.ylabel('Amount')
plt.show()

# %% [markdown]
# Data Imbalance
# This dataset is severely imbalanced since only 0.172% of all transactions are frauds. In order to reduce bias we need to balance the data.

# %%
sns.countplot(x='Class', data=data)
print('Non-fraud transactions: {}%'.format(round(data.Class.value_counts()[0]/len(data)*100.0,2)))
print('Fraud transactions: {}%'.format(round(data.Class.value_counts()[1]/len(data)*100.0,2)))
# Out:
# Non-fraud transactions: 99.83%
# Fraud transactions: 0.17%

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# Model 1 random forest

# %%
X=data.drop(['Class'],axis=1)
y=data['Class']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=123)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
model=rfc.fit(X_train,y_train)

# %%
prediction=model.predict(X_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test,prediction)
# Out:
# 0.9995318516437859

# %% [markdown]
# Model 2 logistic regression

# %%
from sklearn.linear_model import LogisticRegression
X1=data.drop(['Class'],axis=1)
y1=data['Class']
X1_train,X1_test,y1_train,y1_test=train_test_split(X1,y1,test_size=0.3,random_state=123)
lr=LogisticRegression()

# %%
model2=lr.fit(X1_train,y1_train)
prediction2=model2.predict(X1_test)
accuracy_score(y1_test,prediction2)
# Out:
# 0.9989934810341398

# %% [markdown]
# model 3 desion tree

# %%
from sklearn.tree import DecisionTreeRegressor
X2=data.drop(['Class'],axis=1)
y2=data['Class']
dt=DecisionTreeRegressor()
X2_train,X2_test,y2_train,y2_test=train_test_split(X2,y2,test_size=0.3,random_state=123)

# %%
model3=dt.fit(X2_train,y2_train)
prediction3=model3.predict(X2_test)
accuracy_score(y2_test,prediction3)
# Out:
# 0.9991924440855307

# %%
acc=[0.9995318516437859,0.9989934810341398,0.9991924440855307]

# %%
models = ["RandomForestClassifier", 'LogisticRegression','DecisionTreeRegressor']
acc_percentages = [f"{score * 100:.2f}%" for score in acc]
acc_percentages
# Out:
# ['99.95%', '99.90%', '99.92%']

# %%
acc_scores = {"Model": models, "Accuracy Score": acc_percentages}
score_df = pd.DataFrame(acc_scores)
score_df
# Out:
#                     Model Accuracy Score
# 0  RandomForestClassifier         99.95%
# 1      LogisticRegression         99.90%
# 2   DecisionTreeRegressor         99.92%
